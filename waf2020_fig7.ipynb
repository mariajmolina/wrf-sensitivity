# %%
import pysplit
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from mpl_toolkits.basemap import Basemap
import seaborn as sns
import pandas as pd

# %%
"""
all_group_005 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.5*winter20170121*')
print(all_group_005.trajcount)
all_group_006 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.6*winter20170121*')
print(all_group_006.trajcount)
all_group_007 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.7*winter20170121*')
print(all_group_007.trajcount)
all_group_008 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.8*winter20170121*')
print(all_group_008.trajcount)
all_group_009 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.9*winter20170121*')
print(all_group_009.trajcount)
"""

all_group_010 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.0*winter20170121*')
print(all_group_010.trajcount)

"""
all_group_011 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.1*winter20170121*')
print(all_group_011.trajcount)
all_group_012 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.2*winter20170121*')
print(all_group_012.trajcount)
all_group_013 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.3*winter20170121*')
print(all_group_013.trajcount)
all_group_014 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.4*winter20170121*')
print(all_group_014.trajcount)
all_group_015 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.5*winter20170121*')
print(all_group_015.trajcount)
"""
# Out:
# 6050
# "\nall_group_011 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.1*winter20170121*')\nprint(all_group_011.trajcount)\nall_group_012 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.2*winter20170121*')\nprint(all_group_012.trajcount)\nall_group_013 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.3*winter20170121*')\nprint(all_group_013.trajcount)\nall_group_014 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.4*winter20170121*')\nprint(all_group_014.trajcount)\nall_group_015 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.5*winter20170121*')\nprint(all_group_015.trajcount)\n"

# %%
moist_trajlist1 = [traj for traj in all_group_005 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist2 = [traj for traj in all_group_006 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist2))
moist_trajlist3 = [traj for traj in all_group_007 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist3))
moist_trajlist4 = [traj for traj in all_group_008 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist4))
moist_trajlist5 = [traj for traj in all_group_009 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist5))
moist_trajlist6 = [traj for traj in all_group_010 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist6))
moist_trajlist7 = [traj for traj in all_group_011 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist7))
moist_trajlist8 = [traj for traj in all_group_012 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist8))
moist_trajlist9 = [traj for traj in all_group_013 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist9))
moist_trajlist10 = [traj for traj in all_group_014 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist10))
moist_trajlist11 = [traj for traj in all_group_015 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist11))
# Out:
# 6050
# 6050
# 6049
# 6017
# 5875
# 5773
# 5682
# 5593
# 5527
# 5492
# 5469

# %%
"""
two_group_005 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.5*winter20170122*')
print(two_group_005.trajcount)
two_group_006 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.6*winter20170122*')
print(two_group_006.trajcount)
two_group_007 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.7*winter20170122*')
print(two_group_007.trajcount)
two_group_008 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.8*winter20170122*')
print(two_group_008.trajcount)
two_group_009 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.9*winter20170122*')
print(two_group_009.trajcount)
"""

two_group_010 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.0*winter20170122*')
print(two_group_010.trajcount)

"""
two_group_011 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.1*winter20170122*')
print(two_group_011.trajcount)
two_group_012 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.2*winter20170122*')
print(two_group_012.trajcount)
two_group_013 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.3*winter20170122*')
print(two_group_013.trajcount)
two_group_014 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.4*winter20170122*')
print(two_group_014.trajcount)
two_group_015 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.5*winter20170122*')
print(two_group_015.trajcount)
"""
# Out:
# 3630
# "\ntwo_group_011 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.1*winter20170122*')\nprint(two_group_011.trajcount)\ntwo_group_012 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.2*winter20170122*')\nprint(two_group_012.trajcount)\ntwo_group_013 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.3*winter20170122*')\nprint(two_group_013.trajcount)\ntwo_group_014 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.4*winter20170122*')\nprint(two_group_014.trajcount)\ntwo_group_015 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.5*winter20170122*')\nprint(two_group_015.trajcount)\n"

# %%
moist_trajlists1 = [traj for traj in two_group_005 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists1))
moist_trajlists2 = [traj for traj in two_group_006 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists2))
moist_trajlists3 = [traj for traj in two_group_007 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists3))
moist_trajlists4 = [traj for traj in two_group_008 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists4))
moist_trajlists5 = [traj for traj in two_group_009 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists5))
moist_trajlists6 = [traj for traj in two_group_010 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists6))
moist_trajlists7 = [traj for traj in two_group_011 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists7))
moist_trajlists8 = [traj for traj in two_group_012 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists8))
moist_trajlists9 = [traj for traj in two_group_013 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists9))
moist_trajlists10 = [traj for traj in two_group_014 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists10))
moist_trajlists11 = [traj for traj in two_group_015 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlists11))
# Out:
# 3630
# 3608
# 3586
# 3543
# 3513
# 3489
# 3417
# 3285
# 3112
# 2903
# 2728

# %%
"""
thr_group_005 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.5*winter20170123*')
print(thr_group_005.trajcount)
thr_group_006 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.6*winter20170123*')
print(thr_group_006.trajcount)
thr_group_007 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.7*winter20170123*')
print(thr_group_007.trajcount)
thr_group_008 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.8*winter20170123*')
print(thr_group_008.trajcount)
thr_group_009 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl00.9*winter20170123*')
print(thr_group_009.trajcount)
"""

thr_group_010 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.0*winter20170123*')
print(thr_group_010.trajcount)

"""
thr_group_011 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.1*winter20170123*')
print(thr_group_011.trajcount)
thr_group_012 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.2*winter20170123*')
print(thr_group_012.trajcount)
thr_group_013 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.3*winter20170123*')
print(thr_group_013.trajcount)
thr_group_014 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.4*winter20170123*')
print(thr_group_014.trajcount)
thr_group_015 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.5*winter20170123*')
print(thr_group_015.trajcount)
"""
# Out:
# 363
# "\nthr_group_011 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.1*winter20170123*')\nprint(thr_group_011.trajcount)\nthr_group_012 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.2*winter20170123*')\nprint(thr_group_012.trajcount)\nthr_group_013 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.3*winter20170123*')\nprint(thr_group_013.trajcount)\nthr_group_014 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.4*winter20170123*')\nprint(thr_group_014.trajcount)\nthr_group_015 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*pbl01.5*winter20170123*')\nprint(thr_group_015.trajcount)\n"

# %%
moist_trajlist1 = [traj for traj in thr_group_005 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_006 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_007 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_008 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_009 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_010 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_005 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_006 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_007 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_008 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
moist_trajlist1 = [traj for traj in thr_group_009 if traj.data.Relative_Humidity[0] >= 65.0]
print(len(moist_trajlist1))
# Out:
# 363
# 363
# 363
# 363
# 363
# 362
# 363
# 363
# 363
# 363
# 363

# %%
((6050*11)+(3630*11)+(363*11))
# Out:
# 110473

# %%
((len(moist_trajlist1)+len(moist_trajlist2)+len(moist_trajlist3)+len(moist_trajlist4)+\
len(moist_trajlist5)+len(moist_trajlist6)+len(moist_trajlist7)+len(moist_trajlist8)+\
len(moist_trajlist9)+len(moist_trajlist10)+len(moist_trajlist11))+\
(len(moist_trajlists1)+len(moist_trajlists2)+len(moist_trajlists3)+len(moist_trajlists4)+\
len(moist_trajlists5)+len(moist_trajlists6)+len(moist_trajlists7)+len(moist_trajlists8)+\
len(moist_trajlists9)+len(moist_trajlists10)+len(moist_trajlists11))+(363*11))
# Out:
# 98697

# %%
110473-104384
# Out:
# 6089

# %%
6089/((6050*11)+(3630*11)+(363*11))
# Out:
# 0.055117540032406105

# %%
all_group_010 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*ens61.0pbl00.5*winter20170121*')
print(all_group_010.trajcount)

two_group_010 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*ens61.0pbl00.5*winter20170122*')
print(two_group_010.trajcount)

thr_group_010 = pysplit.make_trajectorygroup(r'/glade/scratch/molina/temptrajs_edit/tor*ens61.0pbl00.5*winter20170123*')
print(thr_group_010.trajcount)
# Out:
# 50
# 30
# 3

# %%
"""
from wrf import getvar, get_basemap
from netCDF4 import Dataset

#Create basemap projection for figure using WRF proj
ncfile2_wrf_d02 = Dataset('/glade/scratch/molina/WAF_proj/WAF2019/wrf4km_ens_2/wrfout_d01_2017-01-15_09:00:00')
while True:
    dbz2_wrf_d02 = np.array([0])
    if len(dbz2_wrf_d02) == 1:
        try: 
            dbz2_wrf_d02 = getvar(ncfile2_wrf_d02, "dbz")
        except ValueError:
            continue
    if len(dbz2_wrf_d02) != 1:
        print('File Opened...')
        break
        
bmap = get_basemap(dbz2_wrf_d02)
"""
# Out:
# File Opened...

# %%
cmap = sns.cubehelix_palette(16, start=.5, rot=-.75, as_cmap=True)

norm = mpl.colors.Normalize(vmin=0,vmax=20)

# %%
############################################################################
############################################################################
############################################################################ 


plt.rcParams["axes.axisbelow"] = False


############################################################################
############################################################################
############################################################################ 


fig = plt.figure(figsize=(8.,9.))


############################################################################ 


ax = fig.add_axes([0.0, 0.6325, 0.5, 0.35]) 

ax.set_title('a) 09-21 UTC 21 Jan', fontsize=12)


ax2 = fig.add_axes([0.0, 0.565, 0.5, 0.1]) 


############################################################################ 


bmap = Basemap(llcrnrlon = -105,
               llcrnrlat = 10,
               urcrnrlon = -60,
               urcrnrlat = 37.5,
               projection = 'lcc',
               lat_1 = 10,
               lat_2 = 37.5,
               lon_0 = -80,
               lat_0 = 23.5,
               resolution='l',
               ax=ax)

bmap.drawstates()
bmap.drawcoastlines()
bmap.drawcountries()


############################################################################


for traj in all_group_010[::]:
        
    if pd.to_datetime(traj.data.DateTime[0]).hour <= 21:
        
        bmap_coords = bmap(traj.path.xy[0], traj.path.xy[1])

        cs = bmap.scatter(bmap_coords[0], bmap_coords[1],  
                          s=10, c = traj.data.Specific_Humidity.values,
                          cmap = cmap,
                          vmin=0, vmax=20,
                          edgecolors='none', 
                          zorder=2)

        traj.calculate_distance()

        traj_dist = np.divide(traj.data.Cumulative_Dist.values, 1000)

        z = np.array(traj.path.coords[:])[::,2]

        cs2 = ax2.scatter(traj_dist, z, s=10,
                          c = traj.data.Specific_Humidity.values, 
                          cmap = cmap,
                          vmin=0, vmax=20,
                          edgecolors='none', zorder=2)
     
    
############################################################################

    
ax2.set_ylabel('Height (km)', fontsize=12)

ax2.set_xlim(0, 4000)
ax2.set_ylim(0, 5)

ax2.set_xticks([0,1000,2000,3000,4000])
ax2.set_yticks([0,1000,2000,3000,4000,5000])

ax2.set_xticklabels([' ','1,000','2,000','3,000',' '], fontsize=12)
ax2.set_yticklabels(['0','1','2','3','4','5'], fontsize=12)

ax2.tick_params(axis='x', which='both', direction='in', bottom=True, labelbottom=True)
ax2.tick_params(axis='y', which='both', direction='in', left=True, labelleft=True)

ax2.grid(True, linestyle='--', alpha=0.5)


############################################################################
############################################################################
############################################################################ 


ax3 = fig.add_axes([0.5, 0.6325, 0.5, 0.35]) 

ax3.set_title('b) 21-04 UTC 21-22 Jan', fontsize=12)
    

ax4 = fig.add_axes([0.5, 0.565, 0.5, 0.1]) 

bmap = Basemap(llcrnrlon = -105,
               llcrnrlat = 10,
               urcrnrlon = -60,
               urcrnrlat = 37.5,
               projection = 'lcc',
               lat_1 = 10,
               lat_2 = 37.5,
               lon_0 = -80,
               lat_0 = 23.5,
               resolution='l',
               ax=ax3)


bmap.drawstates()
bmap.drawcoastlines()
bmap.drawcountries()


############################################################################


for traj in all_group_010[::]:
        
    if pd.to_datetime(traj.data.DateTime[0]).hour > 21:

        bmap_coords = bmap(traj.path.xy[0], traj.path.xy[1])

        cs = bmap.scatter(bmap_coords[0], bmap_coords[1],  
                          s=10, c = traj.data.Specific_Humidity.values,
                          cmap = cmap,
                          vmin=0, vmax=20,
                          edgecolors='none', 
                          zorder=2)

        traj.calculate_distance()

        traj_dist = np.divide(traj.data.Cumulative_Dist.values, 1000)

        z = np.array(traj.path.coords[:])[::,2]

        cs2 = ax4.scatter(traj_dist, z, s=10,
                          c = traj.data.Specific_Humidity.values, 
                          cmap = cmap,
                          vmin=0, vmax=20,
                          edgecolors='none', zorder=2)
        

for traj in two_group_010[::]:
    
    if pd.to_datetime(traj.data.DateTime[0]).hour < 4:
        
        bmap_coords = bmap(traj.path.xy[0], traj.path.xy[1])

        cs = bmap.scatter(bmap_coords[0], bmap_coords[1],  
                          s=10, c = traj.data.Specific_Humidity.values,
                          cmap = cmap,
                          vmin=0, vmax=20,
                          edgecolors='none', 
                          zorder=2)

        traj.calculate_distance()

        traj_dist = np.divide(traj.data.Cumulative_Dist.values, 1000)

        z = np.array(traj.path.coords[:])[::,2]

        cs2 = ax4.scatter(traj_dist, z, s=10,
                          c = traj.data.Specific_Humidity.values, 
                          cmap = cmap,
                          vmin=0, vmax=20,
                          edgecolors='none', zorder=2)
     
    
############################################################################

    
ax4.set_xlim(0, 4000)
ax4.set_ylim(0, 5)

ax4.set_xticks([0,1000,2000,3000,4000])
ax4.set_yticks([0,1000,2000,3000,4000,5000])

ax4.set_xticklabels([' ','1,000','2,000','3,000',' '], fontsize=12)
ax4.set_yticklabels(['0','1','2','3','4','5'], fontsize=12)

ax4.tick_params(axis='x', which='both', direction='in', bottom=True, labelbottom=True)
ax4.tick_params(axis='y', which='both', direction='in', left=True, labelleft=False)

ax4.grid(True, linestyle='--', alpha=0.5)


############################################################################
############################################################################
############################################################################ 


ax5 = fig.add_axes([0.0, 0.175, 0.5, 0.35]) 

ax5.set_title('c) 04-23 UTC 22 Jan', fontsize=12)
    

ax6 = fig.add_axes([0.0, 0.106, 0.5, 0.1]) 


bmap = Basemap(llcrnrlon = -105,
               llcrnrlat = 10,
               urcrnrlon = -60,
               urcrnrlat = 37.5,
               projection = 'lcc',
               lat_1 = 10,
               lat_2 = 37.5,
               lon_0 = -80,
               lat_0 = 23.5,
               resolution='l',
               ax=ax5)


bmap.drawstates()
bmap.drawcoastlines()
bmap.drawcountries()


############################################################################


for traj in two_group_010[::]:
    
    if pd.to_datetime(traj.data.DateTime[0]).hour >= 4:
        
        bmap_coords = bmap(traj.path.xy[0], traj.path.xy[1])

        cs = bmap.scatter(bmap_coords[0], bmap_coords[1],  
                          s=10, c = traj.data.Specific_Humidity.values,
                          cmap = cmap,
                          vmin=0, vmax=20,
                          edgecolors='none', 
                          zorder=2)

        traj.calculate_distance()

        traj_dist = np.divide(traj.data.Cumulative_Dist.values, 1000)

        z = np.array(traj.path.coords[:])[::,2]

        cs2 = ax6.scatter(traj_dist, z, s=10,
                          c = traj.data.Specific_Humidity.values, 
                          cmap = cmap,
                          vmin=0, vmax=20,
                          edgecolors='none', zorder=2)
     
    
############################################################################

    
ax6.set_xlabel('Distance (km)', fontsize=12)
ax6.set_ylabel('Height (km)', fontsize=12)

ax6.set_xlim(0, 4000)
ax6.set_ylim(0, 5)

ax6.set_xticks([0,1000,2000,3000,4000])
ax6.set_yticks([0,1000,2000,3000,4000,5000])

ax6.set_xticklabels([' ','1,000','2,000','3,000',' '], fontsize=12)
ax6.set_yticklabels(['0','1','2','3','4','5'], fontsize=12)

ax6.tick_params(axis='x', which='both', direction='in', bottom=True, labelbottom=True)
ax6.tick_params(axis='y', which='both', direction='in', left=True, labelleft=True)

ax6.grid(True, linestyle='--', alpha=0.5)


############################################################################
############################################################################
############################################################################ 


ax7 = fig.add_axes([0.5, 0.175, 0.5, 0.35]) 

ax7.set_title('d) 00-09 UTC 23 Jan', fontsize=12)


ax8 = fig.add_axes([0.5, 0.106, 0.5, 0.1]) 


bmap = Basemap(llcrnrlon = -105,
               llcrnrlat = 10,
               urcrnrlon = -60,
               urcrnrlat = 37.5,
               projection = 'lcc',
               lat_1 = 10,
               lat_2 = 37.5,
               lon_0 = -80,
               lat_0 = 23.5,
               resolution='l',
               ax=ax7)


bmap.drawstates()
bmap.drawcoastlines()
bmap.drawcountries()


############################################################################


for traj in thr_group_010[::]:
        
    bmap_coords = bmap(traj.path.xy[0], traj.path.xy[1])
    
    cs = bmap.scatter(bmap_coords[0], bmap_coords[1],  
                      s=10, c = traj.data.Specific_Humidity.values,
                      cmap = cmap,
                      vmin=0, vmax=20,
                      edgecolors='none', 
                      zorder=2)

    traj.calculate_distance()
        
    traj_dist = np.divide(traj.data.Cumulative_Dist.values, 1000)
        
    z = np.array(traj.path.coords[:])[::,2]

    cs2 = ax8.scatter(traj_dist, z, s=10,
                      c = traj.data.Specific_Humidity.values, 
                      cmap = cmap,
                      vmin=0, vmax=20,
                      edgecolors='none', zorder=2)
     
    
############################################################################

    
ax8.set_xlabel('Distance (km)', fontsize=12)

ax8.set_xlim(0, 4000)
ax8.set_ylim(0, 5)

ax8.set_xticks([0,1000,2000,3000,4000])
ax8.set_yticks([0,1000,2000,3000,4000,5000])

ax8.set_xticklabels([' ','1,000','2,000','3,000',' '], fontsize=12)
ax8.set_yticklabels(['0','1','2','3','4','5'], fontsize=12)

ax8.tick_params(axis='x', which='both', direction='in', bottom=True, labelbottom=True)
ax8.tick_params(axis='y', which='both', direction='in', left=True, labelleft=False)

ax8.grid(True, linestyle='--', alpha=0.5)


############################################################################


cbar_ax = fig.add_axes([0.25, 0.02, 0.5, 0.01125])

bounds = [0,5,10,15,20]

cbar = mpl.colorbar.ColorbarBase(cbar_ax, cmap=cmap,
                                norm=norm,
                                ticks=bounds,
                                orientation='horizontal',
                                extend='max')

cbar.set_label('Specific Humidity (g $\mathregular{kg^{-1}}$)', fontsize=12) 
cbar.ax.tick_params(labelsize=12)
cbar_ax.yaxis.set_ticks_position('left')
cbar_ax.yaxis.set_label_position('left')


############################################################################
############################################################################
############################################################################ 


plt.savefig('/glade/work/molina/DATA/temp_figs/mwr2019_figtrajs.png', bbox_inches='tight', dpi=1200)
plt.savefig('/glade/work/molina/DATA/temp_figs/mwr2019_figtrajs_lowdpi.png', bbox_inches='tight', dpi=200)
plt.show()
plt.close()


############################################################################
############################################################################
############################################################################
