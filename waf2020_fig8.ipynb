# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from wrf import to_np, getvar, get_basemap, latlon_coords, interplevel, smooth2d
from metpy.plots import colortables
from netCDF4 import Dataset
from scipy.ndimage import gaussian_filter as gfilt

cmap = colortables.get_colortable('NWSReflectivity')

# %%
hour='03'
date='21'
file0_wrf_d02 = f"/glade/scratch/molina/wrf4km_ens_2/wrfout_d01_2017-01-{date}_{hour}:00:00"
ncfile0_wrf_d02 = Dataset(file0_wrf_d02)
while True:
    dbz0_wrf_d02 = np.array([0])
    if len(dbz0_wrf_d02) == 1:
        try: 
            dbz0_wrf_d02 = getvar(ncfile0_wrf_d02, "dbz", meta=False)
        except ValueError:
            continue
    if len(dbz0_wrf_d02) != 1:
        print('WRF File Opened...')
        break

hour='09'
date='21'
file1_wrf_d02 = f"/glade/scratch/molina/wrf4km_ens_2/wrfout_d01_2017-01-{date}_{hour}:00:00"
ncfile1_wrf_d02 = Dataset(file1_wrf_d02)
while True:
    dbz1_wrf_d02 = np.array([0])
    if len(dbz1_wrf_d02) == 1:
        try: 
            dbz1_wrf_d02 = getvar(ncfile1_wrf_d02, "dbz", meta=False)
        except ValueError:
            continue
    if len(dbz1_wrf_d02) != 1:
        print('WRF File Opened...')
        break
        
hour='15'
date='21'
file2_wrf_d02 = f"/glade/scratch/molina/wrf4km_ens_2/wrfout_d01_2017-01-{date}_{hour}:00:00"
ncfile2_wrf_d02 = Dataset(file2_wrf_d02)
while True:
    dbz2_wrf_d02 = np.array([0])
    if len(dbz2_wrf_d02) == 1:
        try: 
            dbz2_wrf_d02 = getvar(ncfile2_wrf_d02, "dbz", meta=False)
        except ValueError:
            continue
    if len(dbz2_wrf_d02) != 1:
        print('WRF File Opened...')
        break
        
        
hour='21'
date='21'
file3_wrf_d02 = f"/glade/scratch/molina/wrf4km_ens_2/wrfout_d01_2017-01-{date}_{hour}:00:00"
ncfile3_wrf_d02 = Dataset(file3_wrf_d02)
while True:
    dbz3_wrf_d02 = np.array([0])
    if len(dbz3_wrf_d02) == 1:
        try: 
            dbz3_wrf_d02 = getvar(ncfile3_wrf_d02, "dbz", meta=False)
        except ValueError:
            continue
    if len(dbz3_wrf_d02) != 1:
        print('WRF File Opened...')
        break
        
        
hour='03'
date='22'
file4_wrf_d02 = f"/glade/scratch/molina/wrf4km_ens_2/wrfout_d01_2017-01-{date}_{hour}:00:00"
ncfile4_wrf_d02 = Dataset(file4_wrf_d02)
while True:
    dbz4_wrf_d02 = np.array([0])
    if len(dbz4_wrf_d02) == 1:
        try: 
            dbz4_wrf_d02 = getvar(ncfile4_wrf_d02, "dbz", meta=False)
        except ValueError:
            continue
    if len(dbz4_wrf_d02) != 1:
        print('WRF File Opened...')
        break
        
        
hour='09'
date='22'
file5_wrf_d02 = f"/glade/scratch/molina/wrf4km_ens_2/wrfout_d01_2017-01-{date}_{hour}:00:00"
ncfile5_wrf_d02 = Dataset(file5_wrf_d02)
while True:
    dbz5_wrf_d02 = np.array([0])
    if len(dbz5_wrf_d02) == 1:
        try: 
            dbz5_wrf_d02 = getvar(ncfile5_wrf_d02, "dbz", meta=False)
        except ValueError:
            continue
    if len(dbz5_wrf_d02) != 1:
        print('WRF File Opened...')
        break
        
        
hour='15'
date='22'
file6_wrf_d02 = f"/glade/scratch/molina/wrf4km_ens_2/wrfout_d01_2017-01-{date}_{hour}:00:00"
ncfile6_wrf_d02 = Dataset(file6_wrf_d02)
while True:
    dbz6_wrf_d02 = np.array([0])
    if len(dbz6_wrf_d02) == 1:
        try: 
            dbz6_wrf_d02 = getvar(ncfile6_wrf_d02, "dbz", meta=False)
        except ValueError:
            continue
    if len(dbz6_wrf_d02) != 1:
        print('WRF File Opened...')
        break
        
        
hour='21'
date='22'
file7_wrf_d02 = f"/glade/scratch/molina/wrf4km_ens_2/wrfout_d01_2017-01-{date}_{hour}:00:00"
ncfile7_wrf_d02 = Dataset(file7_wrf_d02)
while True:
    dbz7_wrf_d02 = np.array([0])
    if len(dbz7_wrf_d02) == 1:
        try: 
            dbz7_wrf_d02 = getvar(ncfile7_wrf_d02, "dbz", meta=False)
        except ValueError:
            continue
    if len(dbz7_wrf_d02) != 1:
        print('WRF File Opened...')
        break
        
        
hour='03'
date='23'
file8_wrf_d02 = f"/glade/scratch/molina/wrf4km_ens_2/wrfout_d01_2017-01-{date}_{hour}:00:00"
ncfile8_wrf_d02 = Dataset(file8_wrf_d02)
while True:
    dbz8_wrf_d02 = np.array([0])
    if len(dbz8_wrf_d02) == 1:
        try: 
            dbz8_wrf_d02 = getvar(ncfile8_wrf_d02, "dbz", meta=False)
        except ValueError:
            continue
    if len(dbz8_wrf_d02) != 1:
        print('WRF File Opened...')
        break
# Out:
# WRF File Opened...
# WRF File Opened...
# WRF File Opened...
# WRF File Opened...
# WRF File Opened...
# WRF File Opened...
# WRF File Opened...
# WRF File Opened...
# WRF File Opened...

# %%
ncfile12_wrf_d02 = Dataset(file1_wrf_d02)
bleh = getvar(ncfile12_wrf_d02,"td2")

thecropper1 = 200
thecropper2 = 0

lats4, lons4 = latlon_coords(bleh[thecropper1:,thecropper2:])
bm = get_basemap(bleh[thecropper1:,thecropper2:])

x, y = bm(to_np(lons4), to_np(lats4))

levels=[0,10,20,30,40,50,60,70,80]
levels_gpht = np.arange(520., 588., 6.)

# %%
cmap = colortables.get_colortable('NWSReflectivity')

xmin, ymin = bm(-97, 24)
xmax, ymax = bm(-76, 36)


#########################################################################################
#########################################################################################
#########################################################################################


fig = plt.figure(figsize=(10.,8.5))


##############################################################################  


ax1 = fig.add_axes([0.0, 0.66, 0.33, 0.33])

ax1.set_title("a) 0300 UTC 21 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz0_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

ax1.set_xlim([xmin, xmax])
ax1.set_ylim([ymin, ymax])


##############################################################################  


ax2 = fig.add_axes([0.33, 0.66, 0.33, 0.33])

ax2.set_title("b) 0900 UTC 21 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz1_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

ax2.set_xlim([xmin, xmax])
ax2.set_ylim([ymin, ymax])


############################################################################## 


ax3 = fig.add_axes([0.66, 0.66, 0.33, 0.33])

ax3.set_title("c) 1500 UTC 21 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz2_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

ax3.set_xlim([xmin, xmax])
ax3.set_ylim([ymin, ymax])


##############################################################################  


ax4 = fig.add_axes([0.0, 0.355, 0.33, 0.33])

ax4.set_title("d) 2100 UTC 21 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz3_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

ax4.set_xlim([xmin, xmax])
ax4.set_ylim([ymin, ymax])


##############################################################################  


ax5 = fig.add_axes([0.33, 0.355, 0.33, 0.33])

ax5.set_title("e) 0300 UTC 22 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz4_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

ax5.set_xlim([xmin, xmax])
ax5.set_ylim([ymin, ymax])


##############################################################################  


ax6 = fig.add_axes([0.66, 0.355, 0.33, 0.33])

ax6.set_title("f) 0900 UTC 22 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz5_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

ax6.set_xlim([xmin, xmax])
ax6.set_ylim([ymin, ymax])


##############################################################################  


ax7 = fig.add_axes([0.00, 0.05, 0.33, 0.33])

ax7.set_title("g) 1500 UTC 22 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz6_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

ax7.set_xlim([xmin, xmax])
ax7.set_ylim([ymin, ymax])


##############################################################################  


ax8 = fig.add_axes([0.33, 0.05, 0.33, 0.33])

ax8.set_title("h) 2100 UTC 22 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz7_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

ax8.set_xlim([xmin, xmax])
ax8.set_ylim([ymin, ymax])


##############################################################################  


ax9 = fig.add_axes([0.66, 0.05, 0.33, 0.33])

ax9.set_title("i) 0300 UTC 23 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz8_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

ax9.set_xlim([xmin, xmax])
ax9.set_ylim([ymin, ymax])


##############################################################################  


cbar_ax = fig.add_axes([0.25, 0.06, 0.5, 0.01])

tickss = [0,10,20,30,40,50,60,70,80]
cbar = fig.colorbar(wspd_contours, ticks=tickss, cax=cbar_ax, orientation="horizontal", extend='both')
cbar.ax.set_xticklabels(['0','10','20','30','40','50','60','70','80'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Reflectivity (dBZ)', fontsize=12)


##############################################################################  


plt.savefig('/glade/work/molina/DATA/temp_figs/mwr2019_fig7.png', bbox_inches='tight', dpi=1200)
plt.savefig('/glade/work/molina/DATA/temp_figs/mwr2019_fig7_lowdpi.png', bbox_inches='tight', dpi=200)
plt.show()
plt.close()


##############################################################################

# %%
#colors = pl.cm.magma_r(np.linspace(0,1,len(data.thresholds)))

#the control run
wrf_control_orig_0 = 'wrf4km_ens_2'

data=xr.open_dataset('/glade/work/molina/DATA/jan2017_synoptic/'+wrf_control_orig_0+'/newnewnewver_grid_80_UH_'+str(60)+'_Z_'+str(50)+'.nc')

mask_data = xr.open_dataset('/glade/work/molina/DATA/usstates_shapefiles/newconus_mask_res_80.nc')

redone_data = np.where(mask_data.conus.values,data.UHdbz_dates.resample(time='12H',base=9).sum('time'),0)

# %%
def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    import matplotlib.colors as colors
    #https://stackoverflow.com/questions/18926031/how-to-extract-a-subset-of-a-colormap-as-a-new-colormap-in-matplotlib
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

new_pink = truncate_colormap(plt.cm.get_cmap("binary"), 0.1, 1.0)

# %%
cmap = colortables.get_colortable('NWSReflectivity')

xmin, ymin = bm(-97, 24)
xmax, ymax = bm(-76, 36)


#########################################################################################
#########################################################################################
#########################################################################################


fig = plt.figure(figsize=(8., 9.))

#fig.suptitle('WRF Control-Run', y=0.985, fontsize=12)


##############################################################################  


ax1 = fig.add_axes([0.075, 0.655, 0.45, 0.33])

ax1.set_title("a) 0900 UTC 21 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()
#bm.drawparallels(np.arange(int(15),int(41),10),labels=[1,0,0,0], linewidth=0., fontsize=12)

wspd_contours = bm.contourf(x, y, to_np(dbz1_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

wspd_contours = bm.contour(x, y, to_np(ht_500_1)[thecropper1:,thecropper2:], 
                            levels=levels_gpht, linewidths=1.0,
                            cmap=new_pink)

ax1.set_xlim([xmin, xmax])
ax1.set_ylim([ymin, ymax])


##############################################################################  


ax2 = fig.add_axes([0.525, 0.655, 0.45, 0.33])

ax2.set_title("b) 2100 UTC 21 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz2_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

wspd_contours = bm.contour(x, y, to_np(ht_500_2)[thecropper1:,thecropper2:], 
                            levels=levels_gpht, linewidths=1.0,
                            cmap=new_pink)

ax2.set_xlim([xmin, xmax])
ax2.set_ylim([ymin, ymax])


############################################################################## 


ax3 = fig.add_axes([0.075, 0.3525, 0.45, 0.33])

ax3.set_title("c) 0300 UTC 22 Jan", fontsize=12)#, ha='left')

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()
#bm.drawparallels(np.arange(int(15),int(41),10),labels=[1,0,0,0], linewidth=0., fontsize=12)

wspd_contours = bm.contourf(x, y, to_np(dbz3_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

wspd_contours = bm.contour(x, y, to_np(ht_500_3)[thecropper1:,thecropper2:], 
                            levels=levels_gpht, linewidths=1.0,
                            cmap=new_pink)

ax3.set_xlim([xmin, xmax])
ax3.set_ylim([ymin, ymax])


##############################################################################  


ax4 = fig.add_axes([0.525, 0.3525, 0.45, 0.33])

ax4.set_title("d) 1100 UTC 22 Jan", fontsize=12)#, ha='left')

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz4_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

wspd_contours = bm.contour(x, y, to_np(ht_500_4)[thecropper1:,thecropper2:], 
                            levels=levels_gpht, linewidths=1.0,
                            cmap=new_pink)

ax4.set_xlim([xmin, xmax])
ax4.set_ylim([ymin, ymax])


##############################################################################  


ax5 = fig.add_axes([0.075, 0.05, 0.45, 0.33])

ax5.set_title("e) 1900 UTC 22 Jan", fontsize=12)#, ha='left')

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()
#bm.drawparallels(np.arange(int(15),int(41),10),labels=[1,0,0,0], linewidth=0., fontsize=12)
#bm.drawmeridians(np.arange(int(-95),int(-81),10),labels=[0,0,0,1], linewidth=0.0, fontsize=12) 

wspd_contours = bm.contourf(x, y, to_np(dbz5_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

wspd_contours = bm.contour(x, y, to_np(ht_500_5)[thecropper1:,thecropper2:], 
                            levels=levels_gpht, linewidths=1.0,
                            cmap=new_pink)

ax5.set_xlim([xmin, xmax])
ax5.set_ylim([ymin, ymax])


##############################################################################  


ax6 = fig.add_axes([0.525, 0.05, 0.45, 0.33])

ax6.set_title("f) 0600 UTC 23 Jan", fontsize=12)#, ha='left')

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()
#bm.drawmeridians(np.arange(int(-95),int(-81),10),labels=[0,0,0,1], linewidth=0.0, fontsize=12) 


wspd_contours = bm.contourf(x, y, to_np(dbz6_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)

wspd_contours2 = bm.contour(x, y, to_np(ht_500_6)[thecropper1:,thecropper2:], 
                            levels=levels_gpht, linewidths=1.0,
                            cmap=new_pink)

ax6.set_xlim([xmin, xmax])
ax6.set_ylim([ymin, ymax])


##############################################################################  


cbar_ax = fig.add_axes([0.095, 0.05, 0.4, 0.01])

tickss = [0,10,20,30,40,50,60,70,80]
cbar = fig.colorbar(wspd_contours, ticks=tickss, cax=cbar_ax, orientation="horizontal", extend='both')
cbar.ax.set_xticklabels(['0','10','20','30','40','50','60','70','80'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('dBZ', fontsize=12)


cbar_ax = fig.add_axes([0.55, 0.05, 0.4, 0.01])

import matplotlib as mpl
cmap2 = new_pink
norm = mpl.colors.Normalize(vmin=levels_gpht[0], vmax=levels_gpht[-1])

cb1 = mpl.colorbar.ColorbarBase(cbar_ax, cmap=cmap2,
                                norm=norm,
                                orientation='horizontal',
                                ticks=levels_gpht[::2],
                                extend='both')

cb1.set_label('500-hPa GPH (m)', fontsize=12)
cb1.ax.set_xticklabels(['5200','5320','5440','5560','5680','5800'])
cb1.ax.tick_params(labelsize=12)

#plt.savefig('/glade/work/molina/DATA/temp_figs/mwr2019_fig7.png', bbox_inches='tight', dpi=1200)
plt.show()
plt.close()

##############################################################################

# %%
cmap = colortables.get_colortable('NWSReflectivity')

xmin, ymin = bm(-97, 24)
xmax, ymax = bm(-76, 36)


#########################################################################################
#########################################################################################
#########################################################################################


fig = plt.figure(figsize=(8., 9.))

#fig.suptitle('WRF Control-Run', y=0.985, fontsize=12)


##############################################################################  


ax1 = fig.add_axes([0.075, 0.655, 0.45, 0.33])

ax1.set_title("a) 0900 UTC 21 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()
#bm.drawparallels(np.arange(int(15),int(41),10),labels=[1,0,0,0], linewidth=0., fontsize=12)

wspd_contours = bm.contourf(x, y, to_np(dbz1_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)


ax1.set_xlim([xmin, xmax])
ax1.set_ylim([ymin, ymax])


##############################################################################  


ax2 = fig.add_axes([0.525, 0.655, 0.45, 0.33])

ax2.set_title("b) 2100 UTC 21 Jan", fontsize=12)

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz2_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)


ax2.set_xlim([xmin, xmax])
ax2.set_ylim([ymin, ymax])


############################################################################## 


ax3 = fig.add_axes([0.075, 0.3525, 0.45, 0.33])

ax3.set_title("c) 0300 UTC 22 Jan", fontsize=12)#, ha='left')

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()
#bm.drawparallels(np.arange(int(15),int(41),10),labels=[1,0,0,0], linewidth=0., fontsize=12)

wspd_contours = bm.contourf(x, y, to_np(dbz3_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)


ax3.set_xlim([xmin, xmax])
ax3.set_ylim([ymin, ymax])


##############################################################################  


ax4 = fig.add_axes([0.525, 0.3525, 0.45, 0.33])

ax4.set_title("d) 1100 UTC 22 Jan", fontsize=12)#, ha='left')

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()

wspd_contours = bm.contourf(x, y, to_np(dbz4_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)


ax4.set_xlim([xmin, xmax])
ax4.set_ylim([ymin, ymax])


##############################################################################  


ax5 = fig.add_axes([0.075, 0.05, 0.45, 0.33])

ax5.set_title("e) 1900 UTC 22 Jan", fontsize=12)#, ha='left')

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()
#bm.drawparallels(np.arange(int(15),int(41),10),labels=[1,0,0,0], linewidth=0., fontsize=12)
#bm.drawmeridians(np.arange(int(-95),int(-81),10),labels=[0,0,0,1], linewidth=0.0, fontsize=12) 

wspd_contours = bm.contourf(x, y, to_np(dbz5_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)


ax5.set_xlim([xmin, xmax])
ax5.set_ylim([ymin, ymax])


##############################################################################  


ax6 = fig.add_axes([0.525, 0.05, 0.45, 0.33])

ax6.set_title("f) 0600 UTC 23 Jan", fontsize=12)#, ha='left')

bm.drawcoastlines(linewidth=0.5)
bm.drawcountries()
bm.drawstates()
#bm.drawmeridians(np.arange(int(-95),int(-81),10),labels=[0,0,0,1], linewidth=0.0, fontsize=12) 


wspd_contours = bm.contourf(x, y, to_np(dbz6_wrf_d02)[3,thecropper1:,thecropper2:], 
                            levels=levels,
                            cmap=cmap, vmin=0, vmax=80)


ax6.set_xlim([xmin, xmax])
ax6.set_ylim([ymin, ymax])


##############################################################################  


cbar_ax = fig.add_axes([0.275, 0.05, 0.5, 0.01])

tickss = [0,10,20,30,40,50,60,70,80]
cbar = fig.colorbar(wspd_contours, ticks=tickss, cax=cbar_ax, orientation="horizontal", extend='both')
cbar.ax.set_xticklabels(['0','10','20','30','40','50','60','70','80'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Reflectivity (dBZ)', fontsize=12)


plt.savefig('/glade/work/molina/DATA/temp_figs/mwr2019_fig7.png', bbox_inches='tight', dpi=1200)
plt.savefig('/glade/work/molina/DATA/temp_figs/mwr2019_fig7_lowdpi.png', bbox_inches='tight', dpi=200)
plt.show()
plt.close()

##############################################################################
